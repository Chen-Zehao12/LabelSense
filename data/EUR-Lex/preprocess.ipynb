# %%
import json
from collections import defaultdict
import re
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
state = '80%*1'

with open('origin/eurovoc_concepts.jsonl') as jsonl_file:
    eurovoc_concepts =  [json.loads(concept) for concept in jsonl_file.readlines()]
    eurovoc_concepts = {concept['id']: concept['title'] for concept in eurovoc_concepts}

train = []
with open('origin/train.jsonl') as f:
    for line in f:
        line = json.loads(line)
        train.append({
            'text': "\n".join([line["header"], line["recitals"]] + line["main_body"]),
            'labels': [eurovoc_concepts[label_idx] for label_idx in line['eurovoc_concepts']]
        })

test = []
with open('origin/test.jsonl') as f:
    for line in f:
        line = json.loads(line)
        test.append({
            'text': "\n".join([line["header"], line["recitals"]] + line["main_body"]),
            'labels': [eurovoc_concepts[label_idx] for label_idx in line['eurovoc_concepts']]
        })

with open('origin/dev.jsonl') as f:
    for line in f:
        line = json.loads(line)
        test.append({
            'text': "\n".join([line["header"], line["recitals"]] + line["main_body"]),
            'labels': [eurovoc_concepts[label_idx] for label_idx in line['eurovoc_concepts']]
        })

# %%
# delete \n and \
for line in train:
    line['text'] = line['text'].replace('\n', ' ')
    line['text'] = line['text'].replace('\\', '')

for line in test:
    line['text'] = line['text'].replace('\n', ' ')
    line['text'] = line['text'].replace('\\', '')

# %%
# count classes
train_class_count = defaultdict(int)
test_class_count = defaultdict(int)

for line in train:
    for label in line['labels']:
        train_class_count[label] += 1

for line in test:
    for label in line['labels']:
        test_class_count[label] += 1

unseen_class_count = train_class_count.keys() - test_class_count.keys()

# %%
print('Number of train data:', len(train))
print('Number of test data:', len(test))

print('Number of classes in train data:', len(train_class_count))
print('Number of classes in test data:', len(test_class_count))
print('Number of unseen classes:', len(unseen_class_count))

print('Count of train label:\n', sorted(train_class_count.items(), key=lambda x: -x[1]))
print('Count of test label:\n', sorted(test_class_count.items(), key=lambda x: -x[1]))
# Out:
# Number of train data: 45000
# Number of test data: 12000
# Number of classes in train data: 4108
# Number of classes in test data: 3087
# Number of unseen classes: 1184
# Count of train label:
#  [('import', 3645), ('export refund', 3554), ('pip fruit', 3005), ('fruit vegetable', 3004), ('citrus fruit', 2988), ('import price', 2959), ('award of contract', 2796), ('tariff quota', 2271), ('third country', 2158), ('originating product', 2152), ('import licence', 2152), ('import (EU)', 1897), ('CCT duties', 1714), ('common organisation of markets', 1609), ('health control', 1599), ('agri-monetary policy', 1413), ('Spain', 1391), ('beef', 1296), ('rice', 1295), ('stone fruit', 1259), ('sea fish', 1253), ('veterinary inspection', 1233), ('cereals', 1181), ('white sugar', 1137), ('marketing', 1106), ('grape', 1096), ('EU aid', 1043), ('catch quota', 1034), ('EU Member State', 1027), ('butter', 1009), ('quantitative restriction', 990), ('Germany', 981), ('Portugal', 952), ("ship's flag", 943), ('export licence', 940), ('fishing rights', 933), ('fishing area', 931), ('market approval', 928), ('intervention agency', 909), ('France', 895), ('health certificate', 882), ('animal disease', 881), ('marketing standard', 854), ('production aid', 840), ('agreement (EU)', 839), ('aid system', 827), ('agricultural product', 826), ('United Kingdom', 818), ('Italy', 810), ('appointment of staff', 792), ('milk product', 792), ('EU financing', 774), ('tariff preference', 753), ('derogation from EU law', 751), ('common customs tariff', 747), ('labelling', 744), ('designation of origin', 741), ('swine', 730), ('maize', 730), ('export', 723), ('perennial vegetable', 718), ('pigmeat', 716), ('restoration of customs duties', 703), ('product designation', 699), ('international sanctions', 698), ('cattle', 688), ('milk', 666), ('plant health control', 665), ('foodstuff', 664), ('representative price', 663), ('raw sugar', 659), ('State aid', 649), ('aid to agriculture', 642), ('exchange of information', 622), ('poultrymeat', 616), ('product quality', 612), ('animal nutrition', 608), ('fishing regulations', 605), ('approximation of laws', 601), ('textile product', 595), ('import policy', 577), ('economic sanctions', 575), ('sugar product', 564), ('olive oil', 557), ('sugar', 546), ('minimum price', 540), ('Greece', 540), ('sale', 527), ('China', 519), ('vegetable', 514), ('Combined Nomenclature', 514), ('fresh meat', 503), ('Sweden', 502), ('protocol to an agreement', 501), ('animal product', 495), ('EU waters', 492), ('United States', 484), ('fishery product', 483), ('fruit', 483), ('egg', 481), ('food inspection', 479), ('common wheat', 474), ('Belgium', 471), ('poultry', 465), ('rye', 464), ('Netherlands', 457), ('chemical product', 452), ('seed', 451), ('accession to the European Union', 441), ('appointment of members', 437), ('food safety', 432), ('Romania', 426), ('anti-dumping duty', 425), ('sorghum', 420), ('tariff nomenclature', 420), ('animal plague', 414), ('plant health product', 412), ('supply', 409), ('veterinary legislation', 408), ('European Committee of the Regions', 407), ('intra-EU trade', 400), ('Bulgaria', 393), ('intervention stock', 387), ('sea fishing', 386), ('food additive', 385), ('authorised catch', 384), ('import restriction', 377), ('skimmed milk powder', 376), ('financial aid', 375), ('food aid', 369), ('food processing', 369), ('disclosure of information', 367), ('exemption from customs duties', 362), ('barley', 360), ('viticulture', 354), ('customs regulations', 354), ('foodstuffs legislation', 354), ('Denmark', 353), ('Ireland', 351), ('producer group', 347), ('cereal product', 346), ('scientific apparatus', 341), ('Poland', 341), ('Finland', 341), ('customs duties', 340), ('intervention price', 339), ('action programme', 338), ('fruit product', 336), ('intervention buying', 334), ('location of production', 334), ('wine', 329), ('fishery management', 328), ('public health', 326), ('plant health legislation', 323), ('sheep', 323), ('market intervention', 322), ('meat product', 319), ('health risk', 316), ('common agricultural policy', 315), ('health legislation', 310), ('marketing year', 310), ('Canary Islands', 309), ...
# Count of test label:
#  [('import', 986), ('export refund', 956), ('award of contract', 769), ('import price', 764), ('fruit vegetable', 757), ('citrus fruit', 757), ('pip fruit', 755), ('tariff quota', 596), ('import licence', 595), ('third country', 584), ('originating product', 565), ('import (EU)', 488), ('health control', 448), ('CCT duties', 430), ('common organisation of markets', 407), ('Spain', 407), ('sea fish', 394), ('rice', 365), ('agri-monetary policy', 363), ('catch quota', 339), ('veterinary inspection', 336), ('white sugar', 328), ('beef', 312), ('fishing rights', 308), ('stone fruit', 305), ('cereals', 304), ("ship's flag", 301), ('EU Member State', 294), ('EU aid', 281), ('marketing', 278), ('quantitative restriction', 274), ('fishing area', 270), ('market approval', 268), ('export licence', 264), ('grape', 262), ('butter', 255), ('Portugal', 250), ('Germany', 237), ('Italy', 234), ('France', 230), ('milk product', 224), ('animal disease', 223), ('marketing standard', 223), ('production aid', 223), ('aid system', 212), ('common customs tariff', 211), ('intervention agency', 209), ('United Kingdom', 205), ('EU financing', 205), ('representative price', 204), ('tariff preference', 204), ('restoration of customs duties', 200), ('appointment of staff', 199), ('pigmeat', 196), ('labelling', 195), ('agreement (EU)', 192), ('designation of origin', 192), ('milk', 191), ('product designation', 189), ('State aid', 188), ('international sanctions', 188), ('poultrymeat', 187), ('swine', 187), ('raw sugar', 187), ('health certificate', 186), ('fishing regulations', 185), ('agricultural product', 183), ('export', 180), ('foodstuff', 177), ('exchange of information', 174), ('economic sanctions', 171), ('aid to agriculture', 171), ('derogation from EU law', 168), ('approximation of laws', 167), ('maize', 167), ('EU waters', 165), ('perennial vegetable', 163), ('sugar product', 163), ('plant health control', 163), ('textile product', 158), ('animal product', 157), ('cattle', 157), ('olive oil', 156), ('product quality', 154), ('animal nutrition', 152), ('import policy', 151), ('egg', 150), ('minimum price', 149), ('fishery product', 147), ('sugar', 145), ('Netherlands', 143), ('poultry', 142), ('Combined Nomenclature', 133), ('Sweden', 132), ('Greece', 132), ('appointment of members', 130), ('anti-dumping duty', 128), ('food inspection', 128), ('veterinary legislation', 126), ('China', 126), ('fruit', 124), ('vegetable', 124), ('chemical product', 124), ('Belgium', 122), ('protocol to an agreement', 121), ('common wheat', 120), ('skimmed milk powder', 119), ('fresh meat', 119), ('United States', 118), ('rye', 115), ('tariff nomenclature', 115), ('import restriction', 113), ('plant health product', 113), ('European Committee of the Regions', 112), ('sale', 112), ('meat product', 111), ('authorised catch', 111), ('food safety', 110), ('food processing', 110), ('accession to the European Union', 110), ('disclosure of information', 108), ('supply', 106), ('intra-EU trade', 105), ('food aid', 104), ('Denmark', 104), ('food additive', 102), ('intervention stock', 101), ('fishery management', 100), ('health legislation', 100), ('seed', 100), ('wine', 99), ('animal plague', 99), ('Romania', 99), ('producer group', 98), ('sea fishing', 98), ('Bulgaria', 98), ('Finland', 96), ('EAGGF Guidance Section', 95), ('viticulture', 95), ('exemption from customs duties', 95), ('health risk', 94), ('Poland', 94), ('financial aid', 94), ('fruit product', 94), ('marketing year', 94), ('location of production', 93), ('agro-industry', 93), ('barley', 92), ('customs duties', 91), ('selling price', 90), ('sorghum', 88), ('Ireland', 87), ('common agricultural policy', 87), ('Canary Islands', 86), ('scientific apparatus', 86), ('foodstuffs legislation', 86), ('cereal product', 85), ('syrup', 85), ('dangerous substance', 85), ('customs regulations', 84), ('technical standard', 83), ('supply balance sheet', 82), ('tropical fruit', 80), ('intervention price', 80), ('tariff redu ...

# %%
train_text_length, test_text_length = 0, 0
for line in train:
    train_text_length += len(line['text'])
for line in test:
    test_text_length += len(line['text'])

print('Avg length of train text:', train_text_length / len(train))
print('Avg length of test text:', test_text_length / len(test))
# Out:
# Avg length of train text: 3432.534888888889
# Avg length of test text: 3374.8723333333332

# %%
# label2id
label2id = dict()
cnt = 0

for line in train:
    for label in line['labels']:
        if label not in label2id:
            label2id[label] = cnt
            cnt += 1

for line in test:
    for label in line['labels']:
        if label not in label2id:
            label2id[label] = cnt
            cnt += 1

id2label = {v: k for k, v in label2id.items()}

# %%
# to one label, labels[0] is the rarest one
for line in train:
    minn, minn_label = 20000, ''
    for label in line['labels']:
        if train_class_count[label] < minn:
            minn = train_class_count[label]
            minn_label = label
    if line['labels'][0] != minn_label:
        line['labels'].remove(minn_label)
        line['labels'].insert(0, minn_label)

# %%
# delete long tail data
label_collection = [[] for _ in range(len(train_class_count))]
for line in train:
    idx = label2id[line['labels'][0]]
    label_collection[idx].append(line)

if state == '80%*1':
    threshold = int(np.percentile([len(t) for t in label_collection], 80))
    label_collection = [t[:threshold * 1] for t in label_collection if len(t) >= threshold]

# %%
# refresh label2id
label2id = dict()
for idx, piece in enumerate(label_collection):
    label2id[piece[0]['labels'][0]] = idx

id2label = {v: k for k, v in label2id.items()}

# %%
# delete unseen test
idx = 0
while idx < len(test):
    for label in test[idx]['labels']:
        if label not in label2id:
            test.pop(idx)
            break
    else:
        idx += 1

# %%
with open(f'{state}/id2label.json', 'w') as f:
    json.dump(id2label, f, ensure_ascii=False, indent=2)

with open(f'{state}/label2id.json', 'w') as f:
    json.dump(label2id, f, ensure_ascii=False, indent=2)

# %%
# shuffle train dataset
collection_pointer = [0] * len(label_collection)

shuffle_train = []
global_idx, idx = 0, 0
while global_idx < sum(len(t) for t in label_collection):
    if collection_pointer[idx] < len(label_collection[idx]):
        shuffle_train.append(label_collection[idx][collection_pointer[idx]])
        collection_pointer[idx] += 1
        idx = (idx + 1) % len(label_collection)
        global_idx += 1
    else:
        idx = (idx + 1) % len(label_collection)

# %%
# subset of test
test = test[:len(shuffle_train) * 3]

# %%
print('Number of train data:', len(shuffle_train))
print('Number of test data:', len(test))
# Out:
# Number of train data: 11089
# Number of test data: 1201

# %%
# delete unseen train labels
for line in shuffle_train:
    idx = 0
    while idx < len(line['labels']):
        if line['labels'][idx] not in label2id:
            line['labels'].pop(idx)
        else:
            idx += 1

# %%
# count classes
train_class_count = defaultdict(int)
test_class_count = defaultdict(int)

for line in shuffle_train:
    for label in line['labels']:
        train_class_count[label] += 1

for line in test:
    for label in line['labels']:
        test_class_count[label] += 1

unseen_class_count = train_class_count.keys() - test_class_count.keys()
print('Number of train data:', len(shuffle_train))
print('Number of test data:', len(test))

print('Number of classes in train data:', len(train_class_count))
print('Number of classes in test data:', len(test_class_count))
print('Number of unseen classes:', len(unseen_class_count))

print('Count of train label:\n', sorted(train_class_count.items(), key=lambda x: -x[1]))
print('Count of test label:\n', sorted(test_class_count.items(), key=lambda x: -x[1]))

train_text_length, test_text_length = 0, 0
for line in shuffle_train:
    train_text_length += len(line['text'])
for line in test:
    test_text_length += len(line['text'])

print('Avg length of train text:', train_text_length / len(shuffle_train))
print('Avg length of test text:', test_text_length / len(test))
# Out:
# Number of train data: 11089
# Number of test data: 1201
# Number of classes in train data: 853
# Number of classes in test data: 560
# Number of unseen classes: 293
# Count of train label:
#  [('tariff quota', 652), ('beef', 363), ('quantitative restriction', 319), ('production aid', 313), ('cereals', 284), ('agricultural product', 283), ('common organisation of markets', 274), ('fishing area', 265), ('butter', 261), ('intervention agency', 252), ('cattle', 252), ('swine', 249), ('aid to agriculture', 239), ('milk product', 236), ('rice', 223), ('product designation', 202), ('export licence', 202), ('textile product', 194), ('milk', 191), ('citrus fruit', 190), ('import policy', 187), ('pigmeat', 182), ('Greece', 180), ('derogation from EU law', 178), ('product quality', 177), ('fishing regulations', 176), ('import price', 175), ('sugar', 174), ('olive oil', 172), ('export', 171), ('poultry', 167), ('China', 166), ('fresh meat', 165), ('fishery product', 162), ('veterinary legislation', 154), ('poultrymeat', 153), ('seed', 152), ('viticulture', 151), ('Romania', 150), ('foodstuffs legislation', 145), ('Netherlands', 143), ('chemical product', 142), ('tariff nomenclature', 141), ('Sweden', 140), ('food additive', 140), ('white sugar', 139), ('anti-dumping duty', 138), ('producer group', 138), ('sale', 137), ('minimum price', 137), ('animal plague', 136), ('food processing', 131), ('maize', 130), ('wine', 130), ('import restriction', 127), ('intervention stock', 127), ('plant health product', 127), ('Belgium', 125), ('egg', 122), ('EU waters', 121), ('plant health legislation', 119), ('health risk', 118), ('marketing year', 117), ('United States', 116), ('fruit', 116), ('Bulgaria', 116), ('intra-EU trade', 112), ('sea fishing', 112), ('fruit product', 106), ('Poland', 105), ('Ireland', 105), ('meat product', 103), ('Finland', 103), ('stone fruit', 101), ('human nutrition', 97), ('agro-industry', 96), ('action programme', 96), ('skimmed milk powder', 94), ('fishery management', 94), ('terrorism', 93), ('Canary Islands', 93), ('grape', 92), ('intervention buying', 92), ('location of production', 92), ('private stock', 92), ('disease prevention', 91), ('customs regulations', 90), ('health legislation', 90), ('Austria', 89), ('EAGGF Guarantee Section', 86), ('food aid', 86), ('Denmark', 84), ('supply balance sheet', 84), ('foot-and-mouth disease', 84), ('Norway', 83), ('India', 82), ('customs duties', 81), ('research body', 80), ('authorised catch', 79), ('trade restriction', 79), ('scientific apparatus', 78), ('intervention price', 78), ('market intervention', 78), ('pharmaceutical product', 78), ('raw sugar', 77), ('purchase price', 77), ('oleaginous plant', 77), ('plant disease', 76), ('administrative cooperation', 76), ('agri-monetary policy', 76), ('carcase', 76), ('Switzerland', 76), ('tobacco', 75), ('Yugoslavia', 74), ('veterinary drug', 74), ('live animal', 73), ('storage', 72), ('potato', 72), ('aquaculture', 72), ('agricultural guidance', 72), ('cotton', 72), ('ACP countries', 72), ('cereal product', 72), ('conservation of fish stocks', 72), ('Cyprus', 72), ('association agreement (EU)', 71), ('goat', 71), ('Hungary', 70), ('withdrawal from the market', 70), ('sheepmeat', 70), ('meat processing industry', 70), ('Afghanistan', 70), ('sugar product', 68), ('utilised agricultural area', 68), ('animal feedingstuffs', 68), ('consumer information', 68), ('plant propagation', 67), ('tropical fruit', 66), ('agricultural levy', 66), ('common agricultural policy', 66), ('common wheat', 64), ('monetary compensatory amount', 64), ('common fisheries policy', 64), ('crop production', 63), ('selling price', 63), ('parasitology', 62), ('transitional period (EU)', 62), ('specification of tariff heading', 62), ('Israel', 62), ('fresh vegetable', 61), ('distillation', 61), ('free circulation', 61), ('toxic substance', 61), ('interim agreement (EU)', 61), ('EU production', 60), ('clothing', 60), ('rye', 60), ('natural person', 60), ('Thailand', 60), ('catch by species', 60), ('Russia', 60), ('fishing vessel', 60), ('dangerous substance', 59), ('trade agreement', 59), ('Community certification', 59), ('GATT', 58), ('export (EU)', ...
# Count of test label:
#  [('production aid', 102), ('tariff quota', 86), ('common organisation of markets', 59), ('export licence', 54), ('butter', 53), ('cotton', 52), ('quantitative restriction', 52), ('milk product', 51), ('world market price', 47), ('milk', 47), ('olive oil', 47), ('pigmeat', 46), ('product quality', 45), ('aid to agriculture', 42), ('intervention stock', 42), ('intervention agency', 41), ('food processing', 41), ('cereals', 40), ('beef', 40), ('minimum price', 39), ('production refund', 38), ('marketing year', 38), ('sugar', 37), ('white sugar', 35), ('intervention price', 33), ('producer group', 32), ('stone fruit', 32), ('rice', 32), ('market intervention', 31), ('private stock', 31), ('Greece', 31), ('fruit product', 28), ('textile product', 28), ('swine', 27), ('sale', 27), ('grape', 26), ('skimmed milk powder', 26), ('export', 26), ('import price', 25), ('wine', 24), ('sheepmeat', 24), ('reference price', 24), ('fishery product', 24), ('starch', 23), ('agricultural product', 23), ('tobacco', 23), ('agricultural guidance', 22), ('storage', 22), ('storage premium', 22), ('intervention buying', 22), ('viticulture', 21), ('purchase price', 20), ('citrus fruit', 20), ('table wine', 20), ('storage cost', 19), ('carcase', 19), ('economic support', 19), ('withdrawal from the market', 18), ('potato', 18), ('dried product', 18), ('representative rate', 18), ('contract', 18), ('distillation', 18), ('import policy', 18), ('guarantee threshold', 17), ('discount sale', 17), ('producer co-responsibility', 17), ('United States', 17), ('sugar levy', 16), ('fixing of prices', 16), ('leguminous vegetable', 16), ('cheese', 16), ('cream', 16), ('oleaginous plant', 16), ('Belgium', 16), ('public stock', 15), ('supply balance sheet', 15), ('Poland', 15), ('cattle', 15), ('GATT', 15), ('Netherlands', 15), ('agro-industry', 15), ('oil seed rape', 14), ('egg', 14), ('industrial product', 14), ('production quota', 14), ('selling price', 14), ('agri-monetary policy', 14), ('farm prices', 14), ('supplementary aid for products', 14), ('tariff nomenclature', 14), ('threshold price', 14), ('food aid', 14), ('regulation of agricultural production', 13), ('import restriction', 13), ('target price', 13), ('terms for aid', 13), ('marketing restriction', 13), ('animal plague', 13), ('flax', 12), ('agricultural levy', 12), ('seed', 12), ('skimmed milk', 12), ('meat processing industry', 12), ('hemp', 11), ('poultrymeat', 11), ('export restriction', 11), ('Ireland', 11), ('goatmeat', 11), ('derogation from EU law', 11), ('sugar beet', 11), ('plant health legislation', 11), ('pharmaceutical product', 11), ('raw sugar', 11), ('classification', 11), ('suspension of customs duties', 11), ('withdrawal price', 10), ('import levy', 10), ('Madeira', 10), ('vegetable product', 10), ('administrative formalities', 10), ('vinification', 10), ('common price policy', 10), ('price fixed in advance', 10), ('hops', 10), ('fishery resources', 10), ('EU production', 10), ('plant health product', 10), ('frozen product', 10), ('indemnification', 10), ('chemical product', 10), ('milk by-product', 10), ('guarantee', 9), ('sunflower', 9), ('sugar product', 9), ('slaughter premium', 9), ('concentrated product', 9), ('Turkey', 9), ('enlargement of the Union', 9), ('leaf vegetable', 9), ('preserved product', 9), ('trade agreement', 9), ('Sweden', 9), ('fodder', 9), ('agricultural quota', 9), ('dangerous substance', 9), ('French overseas department and region', 9), ('veterinary legislation', 9), ('maize', 9), ('Azores', 9), ('Canary Islands', 9), ('chemical industry', 8), ('market support', 8), ('fishing fleet', 8), ('tariff ceiling', 8), ('countervailing charge', 8), ('sugar refining', 8), ('association agreement (EU)', 8), ('soft fruit', 8), ('distributive trades', 8), ('foot-and-mouth disease', 8), ('monetary compensatory amount', 8), ('standard', 8), ('agricultural product nomenclature', 8), ('Austria', 8), ('vineyard', 7), ('cereal product', 7), ('preparation for market', 7), ('isoglu ...
# Avg length of train text: 3488.007665253855
# Avg length of test text: 3237.6869275603663

# %%
# add label description
with open('label-description.jsonl') as f:
    label_desc = f.readlines()
    label_desc = list(map(json.loads, label_desc))
    label_desc = {line['label']: line['description'] for line in label_desc}

for line in shuffle_train:
    label_text = line['labels'][0]
    for i, label in enumerate(line['labels']):
        line['labels'][i] = label2id[label]
    line['label_description'] = label_desc[label_text]

for line in test:
    label_text = line['labels'][0]
    for i, label in enumerate(line['labels']):
        line['labels'][i] = label2id[label]
    line['label_description'] = label_desc[label_text]

with open(f'{state}/train.json', 'w') as f:
    json.dump(shuffle_train, f, ensure_ascii=False, indent=2)

with open(f'{state}/test.json', 'w') as f:
    json.dump(test, f, ensure_ascii=False, indent=2)

# %%
# add label description
with open('label-description-with-example.jsonl') as f:
    label_desc = f.readlines()
    label_desc = list(map(json.loads, label_desc))
    label_desc = {line['label']: line['description'] for line in label_desc}

for line in shuffle_train:
    label_text = id2label[line['labels'][0]]
    line['label_description'] = label_desc[label_text]

for line in test:
    label_text = id2label[line['labels'][0]]
    line['label_description'] = label_desc[label_text]

with open(f'{state}/train-with-example.json', 'w') as f:
    json.dump(shuffle_train, f, ensure_ascii=False, indent=2)

with open(f'{state}/test-with-example.json', 'w') as f:
    json.dump(test, f, ensure_ascii=False, indent=2)
