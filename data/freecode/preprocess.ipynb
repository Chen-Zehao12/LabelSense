# %%
import json
from collections import defaultdict
import re
import numpy as np
import random
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
state = '98%*1'

data_df = pd.read_csv('origin/freecode_data.csv', index_col=0)
data = [{'text': line[1]['question'], 'labels': line[1]['tag'].split()} for line in data_df.iterrows()]

# %%
train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
# delete \n and \
for line in train:
    line['text'] = line['text'].replace('\n', ' ')
    line['text'] = line['text'].replace('\\', '')

for line in test:
    line['text'] = line['text'].replace('\n', ' ')
    line['text'] = line['text'].replace('\\', '')

# %%
# count classes
train_class_count = defaultdict(int)
test_class_count = defaultdict(int)

for line in train:
    for label in line['labels']:
        train_class_count[label] += 1

for line in test:
    for label in line['labels']:
        test_class_count[label] += 1

unseen_class_count = train_class_count.keys() - test_class_count.keys()

# %%
print('Number of train data:', len(train))
print('Number of test data:', len(test))

print('Number of classes in train data:', len(train_class_count))
print('Number of classes in test data:', len(test_class_count))
print('Number of unseen classes:', len(unseen_class_count))

print('Count of train label:\n', sorted(train_class_count.items(), key=lambda x: -x[1]))
print('Count of test label:\n', sorted(test_class_count.items(), key=lambda x: -x[1]))
# Out:
# Number of train data: 37596
# Number of test data: 9399
# Number of classes in train data: 8005
# Number of classes in test data: 3411
# Number of unseen classes: 5589
# Count of train label:
#  [('Software-Development', 7749), ('Internet', 6564), ('Web', 5082), ('Libraries', 4621), ('multimedia', 3867), ('Communications', 3557), ('Utilities', 2622), ('Dynamic-Content', 2592), ('Networking', 2274), ('Scientific/Engineering', 2182), ('Games/Entertainment', 2023), ('Desktop-Environment', 1883), ('Graphics', 1829), ('Database', 1771), ('Sound/Audio', 1691), ('Text-Processing', 1668), ('Security', 1574), ('Office/Business', 1515), ('Monitoring', 1505), ('Systems-Administration', 1475), ('Email', 1358), ('GPL', 1172), ('Site-Management', 1096), ('Information-Management', 1073), ('Markup', 947), ('Java-Libraries', 928), ('education', 817), ('Chat', 800), ('Archiving', 770), ('php-classes', 664), ('CGI-Tools/Libraries', 649), ('Video', 646), ('Front-Ends', 642), ('Application-Frameworks', 620), ('Testing', 582), ('XML', 558), ('Players', 545), ('Mathematics', 533), ('Visualization', 533), ('Code-Generators', 517), ('GNOME', 516), ('Linux', 507), ('Text-Editors', 500), ('Filters', 498), ('Cryptography', 491), ('HTTP-Servers', 477), ('Financial', 461), ('File-Sharing', 445), ('Build-Tools', 415), ('Documentation', 414), ('Compilers', 405), ('Logging', 401), ('Hardware', 398), ('Python-Modules', 398), ('PHP', 397), ('Operating-Systems', 384), ('Firewalls', 378), ('User-Interfaces', 376), ('Interpreters', 375), ('backup', 371), ('Viewers', 369), ('Filesystems', 366), ('Scheduling', 362), ('Java', 362), ('IRC', 360), ('MP3', 360), ('KDE', 347), ('Indexing/Search', 345), ('Operating-System-Kernels', 334), ('Puzzle-Games', 333), ('Version-Control', 333), ('HTML/XHTML', 328), ('Window-Manager', 327), ('Arcade', 325), ('Editors', 324), ('Installation/Setup', 321), ('groupware', 316), ('FTP', 315), ('Log-Analysis', 314), ('Database-Engines/Servers', 308), ('Perl-Modules', 308), ('Clustering/Distributed-Networks', 297), ('Quality-Assurance', 292), ('Artificial-Intelligence', 291), ('Presentation', 288), ('tools', 274), ('News/Diary', 273), ('Browsers', 272), ('Conversion', 271), ('API', 252), ('Terminals', 251), ('Telephony', 245), ('Widget-Sets', 245), ('Capture', 242), ('Library', 237), ('Linux-Distributions', 237), ('3D-Rendering', 233), ('Debuggers', 229), ('Graphics-Conversion', 227), ('Embedded-Systems', 226), ('Role-Playing', 222), ('Proxy-Servers', 221), ('DNS', 220), ('Other/Nonlisted-Topic', 216), ('Post-Office', 216), ('Document-Repositories', 213), ('printing', 207), ('Simulation', 204), ('Accounting', 198), ('Software-Distribution', 197), ('CD-Audio', 194), ('Turn-Based-Strategy', 194), ('Bioinformatics', 192), ('Mail-Transport-Agents', 191), ('Message-Boards', 190), ('Email-Clients-(MUA)', 190), ('Software-Distribution-Tools', 187), ('Python', 187), ('Emulators', 180), ('framework', 169), ('File-Managers', 167), ('Shells', 165), ('Boot', 164), ('Issue-Tracking', 160), ('Records-Management', 160), ('Bug-Tracking', 158), ('Compression', 158), ('POP3', 155), ('Linguistic', 155), ('LGPL', 151), ('Display', 148), ('Artistic-Software', 147), ('POSIX', 146), ('Conferencing', 145), ('Game', 144), ('Diagnostics', 143), ('Integrated-Development-Environments-(IDE)', 142), ('3D-Modeling', 137), ('Astronomy', 135), ('Analysis', 133), ('MIDI', 133), ('Geographical', 131), ('General', 131), ('Usenet-News', 130), ('Packaging', 129), ('Wiki', 129), ('Capture/Recording', 123), ('JavaScript', 123), ('Applets', 122), ('IMAP', 122), ('Window-Maker', 121), ('Object-Brokering', 121), ('Network', 121), ('Internet-Phone', 117), ('CMS', 116), ('Medical-Science', 116), ('Recovery-Tools', 114), ('Workflow-Frameworks', 113), ('php-class', 113), ('mud', 111), ('Computer-Aided-Instruction-(CAI)', 108), ('TeX/LaTeX', 108), ('Development', 104), ('CVS', 104), ('Electronic-Design-Automation-(EDA)', 104), ('MySQL', 103), ('Home-Automation', 103), ('Benchmark', 102), ('Games', 101), ('Chemistry', 100), ('Audio', 99), ('BBS', 99), ('Sound-Synthesis', 97), ('Metadata/Semantic-Models', 96), ('GPLv3', 96), ('Indexing', 95), ('Windows', 95), ('First-Person-Shoo ...
# Count of test label:
#  [('Software-Development', 1906), ('Internet', 1607), ('Web', 1234), ('Libraries', 1137), ('multimedia', 966), ('Communications', 921), ('Utilities', 693), ('Dynamic-Content', 640), ('Networking', 567), ('Games/Entertainment', 522), ('Scientific/Engineering', 505), ('Desktop-Environment', 489), ('Text-Processing', 474), ('Graphics', 452), ('Database', 444), ('Sound/Audio', 415), ('Security', 404), ('Monitoring', 370), ('Systems-Administration', 369), ('Office/Business', 363), ('Email', 310), ('GPL', 278), ('Information-Management', 276), ('Site-Management', 264), ('Markup', 249), ('Java-Libraries', 225), ('Chat', 206), ('education', 198), ('Archiving', 179), ('Video', 179), ('php-classes', 160), ('Application-Frameworks', 159), ('Front-Ends', 154), ('XML', 152), ('Testing', 149), ('Players', 146), ('CGI-Tools/Libraries', 146), ('Filters', 138), ('Text-Editors', 135), ('Financial', 132), ('Mathematics', 128), ('Linux', 125), ('Code-Generators', 125), ('GNOME', 124), ('Visualization', 119), ('Cryptography', 118), ('HTTP-Servers', 117), ('File-Sharing', 111), ('Operating-Systems', 108), ('Build-Tools', 105), ('Hardware', 105), ('Python-Modules', 105), ('Java', 101), ('Filesystems', 100), ('Interpreters', 100), ('Compilers', 97), ('Indexing/Search', 96), ('Firewalls', 95), ('Documentation', 94), ('PHP', 94), ('IRC', 92), ('Version-Control', 90), ('Installation/Setup', 90), ('MP3', 90), ('HTML/XHTML', 89), ('User-Interfaces', 89), ('Operating-System-Kernels', 86), ('Window-Manager', 85), ('backup', 84), ('Editors', 83), ('Logging', 83), ('Terminals', 82), ('Viewers', 81), ('Quality-Assurance', 80), ('Arcade', 77), ('KDE', 74), ('Presentation', 74), ('Puzzle-Games', 74), ('groupware', 73), ('News/Diary', 72), ('tools', 72), ('Database-Engines/Servers', 71), ('Log-Analysis', 70), ('Document-Repositories', 70), ('Linux-Distributions', 70), ('Library', 69), ('Capture', 69), ('Conversion', 67), ('API', 62), ('Scheduling', 61), ('Perl-Modules', 61), ('FTP', 60), ('Widget-Sets', 60), ('3D-Rendering', 59), ('Clustering/Distributed-Networks', 59), ('Artificial-Intelligence', 59), ('Role-Playing', 59), ('Telephony', 58), ('Debuggers', 57), ('Graphics-Conversion', 56), ('Turn-Based-Strategy', 55), ('Other/Nonlisted-Topic', 55), ('printing', 53), ('Email-Clients-(MUA)', 53), ('Browsers', 53), ('Emulators', 53), ('DNS', 52), ('Python', 51), ('Post-Office', 49), ('Accounting', 49), ('Simulation', 48), ('Integrated-Development-Environments-(IDE)', 47), ('Proxy-Servers', 47), ('Embedded-Systems', 46), ('Records-Management', 45), ('Software-Distribution-Tools', 44), ('Software-Distribution', 44), ('CD-Audio', 43), ('Compression', 43), ('File-Managers', 43), ('Mail-Transport-Agents', 43), ('Shells', 42), ('Message-Boards', 42), ('Game', 41), ('Display', 40), ('Linguistic', 39), ('POP3', 38), ('LGPL', 38), ('Issue-Tracking', 37), ('Artistic-Software', 36), ('Analysis', 36), ('CMS', 36), ('Bioinformatics', 36), ('Boot', 36), ('Recovery-Tools', 35), ('Medical-Science', 34), ('Terminal-Emulators/X-Terminals', 34), ('Network', 34), ('POSIX', 34), ('Bug-Tracking', 34), ('General', 34), ('Packaging', 34), ('Diagnostics', 33), ('TeX/LaTeX', 33), ('3D-Modeling', 32), ('Object-Brokering', 32), ('MySQL', 32), ('mud', 31), ('MIDI', 30), ('IMAP', 30), ('Command-Line', 30), ('Usenet-News', 30), ('CD-Based', 30), ('Computer-Aided-Instruction-(CAI)', 29), ('BBS', 29), ('framework', 29), ('XSL/XSLT', 29), ('fonts', 28), ('Astronomy', 28), ('Web-Application', 28), ('Wiki', 28), ('CVS', 27), ('Window-Maker', 27), ('Benchmark', 27), ('Applets', 27), ('First-Person-Shooters', 26), ('Conferencing', 26), ('Indexing', 26), ('JavaScript', 26), ('Subversion', 26), ('Freeware', 25), ('Metadata/Semantic-Models', 25), ('Internet-Phone', 25), ('AOL-Instant-Messenger', 24), ('Electronic-Design-Automation-(EDA)', 24), ('Android', 24), ('Office-Suites', 23), ('Home-Automation', 23), ('C++', 23), ('HTML', 23), ('Point-Of-Sale', 23), ('Windows', 23), ('music', 22), ('GUI', 22), ('Che ...

# %%
train_text_length, test_text_length = 0, 0
for line in train:
    train_text_length += len(line['text'])
for line in test:
    test_text_length += len(line['text'])

print('Avg length of train text:', train_text_length / len(train))
print('Avg length of test text:', test_text_length / len(test))
# Out:
# Avg length of train text: 317.38094478135974
# Avg length of test text: 314.44260027662517

# %%
# label2id
label2id = dict()
cnt = 0

for line in train:
    for label in line['labels']:
        if label not in label2id:
            label2id[label] = cnt
            cnt += 1

for line in test:
    for label in line['labels']:
        if label not in label2id:
            label2id[label] = cnt
            cnt += 1

id2label = {v: k for k, v in label2id.items()}

# %%
# to one label, labels[0] is the rarest one
for line in train:
    minn, minn_label = 20000, ''
    for label in line['labels']:
        if train_class_count[label] < minn:
            minn = train_class_count[label]
            minn_label = label
    if line['labels'][0] != minn_label:
        line['labels'].remove(minn_label)
        line['labels'].insert(0, minn_label)

# %%
# delete long tail data
label_collection = [[] for _ in range(len(train_class_count))]
for line in train:
    idx = label2id[line['labels'][0]]
    label_collection[idx].append(line)

if state == '98%*1':
    threshold = int(np.percentile([len(t) for t in label_collection], 98))
    label_collection = [t[:threshold * 1] for t in label_collection if len(t) >= threshold]

# %%
# refresh label2id
label2id = dict()
for idx, piece in enumerate(label_collection):
    label2id[piece[0]['labels'][0]] = idx

id2label = {v: k for k, v in label2id.items()}

# %%
# delete unseen test
idx = 0
while idx < len(test):
    for label in test[idx]['labels']:
        if label not in label2id:
            test.pop(idx)
            break
    else:
        idx += 1

# %%
with open(f'{state}/id2label.json', 'w') as f:
    json.dump(id2label, f, ensure_ascii=False, indent=2)

with open(f'{state}/label2id.json', 'w') as f:
    json.dump(label2id, f, ensure_ascii=False, indent=2)

# %%
# shuffle train dataset
collection_pointer = [0] * len(label_collection)

shuffle_train = []
global_idx, idx = 0, 0
while global_idx < sum(len(t) for t in label_collection):
    if collection_pointer[idx] < len(label_collection[idx]):
        shuffle_train.append(label_collection[idx][collection_pointer[idx]])
        collection_pointer[idx] += 1
        idx = (idx + 1) % len(label_collection)
        global_idx += 1
    else:
        idx = (idx + 1) % len(label_collection)

# %%
# subset of test
test = test[:len(shuffle_train) * 3]

# %%
print('Number of train data:', len(shuffle_train))
print('Number of test data:', len(test))
# Out:
# Number of train data: 10854
# Number of test data: 5417

# %%
# delete unseen train labels
for line in shuffle_train:
    idx = 0
    while idx < len(line['labels']):
        if line['labels'][idx] not in label2id:
            line['labels'].pop(idx)
        else:
            idx += 1

# %%
# count classes
train_class_count = defaultdict(int)
test_class_count = defaultdict(int)

for line in shuffle_train:
    for label in line['labels']:
        train_class_count[label] += 1

for line in test:
    for label in line['labels']:
        test_class_count[label] += 1

unseen_class_count = train_class_count.keys() - test_class_count.keys()
print('Number of train data:', len(shuffle_train))
print('Number of test data:', len(test))

print('Number of classes in train data:', len(train_class_count))
print('Number of classes in test data:', len(test_class_count))
print('Number of unseen classes:', len(unseen_class_count))

print('Count of train label:\n', sorted(train_class_count.items(), key=lambda x: -x[1]))
print('Count of test label:\n', sorted(test_class_count.items(), key=lambda x: -x[1]))

train_text_length, test_text_length = 0, 0
for line in shuffle_train:
    train_text_length += len(line['text'])
for line in test:
    test_text_length += len(line['text'])

print('Avg length of train text:', train_text_length / len(shuffle_train))
print('Avg length of test text:', test_text_length / len(test))
# Out:
# Number of train data: 10854
# Number of test data: 5417
# Number of classes in train data: 162
# Number of classes in test data: 147
# Number of unseen classes: 15
# Count of train label:
#  [('Software-Development', 2684), ('Internet', 2338), ('Web', 1747), ('Communications', 1534), ('Libraries', 1492), ('Dynamic-Content', 996), ('Scientific/Engineering', 975), ('Utilities', 888), ('Games/Entertainment', 754), ('Office/Business', 718), ('Graphics', 707), ('Text-Processing', 691), ('Desktop-Environment', 663), ('Email', 627), ('Sound/Audio', 622), ('Database', 605), ('Networking', 574), ('Information-Management', 571), ('Systems-Administration', 464), ('Security', 437), ('Site-Management', 416), ('Archiving', 414), ('Monitoring', 387), ('education', 350), ('Java-Libraries', 325), ('Chat', 264), ('CGI-Tools/Libraries', 250), ('Video', 234), ('Visualization', 231), ('Financial', 230), ('Front-Ends', 225), ('Players', 216), ('Testing', 215), ('Application-Frameworks', 215), ('php-classes', 206), ('Text-Editors', 193), ('groupware', 184), ('Filters', 180), ('Code-Generators', 173), ('Version-Control', 172), ('Documentation', 171), ('Indexing/Search', 168), ('Scheduling', 165), ('Viewers', 164), ('XML', 163), ('File-Sharing', 162), ('backup', 160), ('Mathematics', 158), ('Hardware', 158), ('HTTP-Servers', 158), ('Build-Tools', 155), ('User-Interfaces', 155), ('Logging', 155), ('GNOME', 153), ('Installation/Setup', 152), ('Python-Modules', 150), ('Filesystems', 145), ('Window-Manager', 140), ('Document-Repositories', 132), ('3D-Rendering', 130), ('Message-Boards', 130), ('HTML/XHTML', 129), ('Editors', 129), ('News/Diary', 128), ('Clustering/Distributed-Networks', 126), ('Bioinformatics', 126), ('Cryptography', 123), ('Compilers', 122), ('Interpreters', 122), ('Telephony', 120), ('Operating-System-Kernels', 120), ('Role-Playing', 119), ('Presentation', 119), ('Quality-Assurance', 118), ('Artificial-Intelligence', 116), ('Firewalls', 116), ('POP3', 114), ('Email-Clients-(MUA)', 114), ('KDE', 112), ('Mail-Transport-Agents', 110), ('Database-Engines/Servers', 109), ('FTP', 106), ('Software-Distribution-Tools', 106), ('Perl-Modules', 105), ('tools', 104), ('Browsers', 103), ('Simulation', 101), ('Conversion', 100), ('Other/Nonlisted-Topic', 100), ('Log-Analysis', 99), ('Conferencing', 99), ('Accounting', 99), ('MP3', 97), ('Records-Management', 97), ('Arcade', 95), ('Widget-Sets', 94), ('Debuggers', 93), ('Artistic-Software', 92), ('Linux-Distributions', 91), ('MIDI', 91), ('Embedded-Systems', 90), ('Puzzle-Games', 88), ('IRC', 88), ('Proxy-Servers', 88), ('Linguistic', 86), ('Graphics-Conversion', 85), ('API', 84), ('Bug-Tracking', 83), ('IMAP', 83), ('Compression', 81), ('Medical-Science', 81), ('Diagnostics', 80), ('GPL', 80), ('printing', 80), ('Workflow-Frameworks', 79), ('3D-Modeling', 79), ('Display', 79), ('General', 79), ('Boot', 78), ('Turn-Based-Strategy', 78), ('mud', 77), ('Packaging', 75), ('Object-Brokering', 75), ('Wiki', 75), ('Shells', 74), ('Capture/Recording', 74), ('Recovery-Tools', 74), ('File-Managers', 74), ('DNS', 73), ('Astronomy', 73), ('Address-Book', 73), ('Electronic-Design-Automation-(EDA)', 73), ('Internet-Phone', 72), ('First-Person-Shooters', 72), ('Computer-Aided-Instruction-(CAI)', 71), ('Metadata/Semantic-Models', 71), ('Benchmark', 70), ('Mirroring', 70), ('Geographical', 70), ('Usenet-News', 69), ('Emulators', 69), ('Integrated-Development-Environments-(IDE)', 69), ('Home-Automation', 69), ('Indexing', 69), ('CVS', 69), ('BBS', 69), ('Chemistry', 69), ('Sound-Synthesis', 68), ('GPLv3', 68), ('TeX/LaTeX', 68), ('Link-Checking', 67), ('php-class', 67), ('Window-Maker', 67), ('LGPL', 67), ('Point-Of-Sale', 67), ('BSD-Original', 67), ('Ruby-Modules', 67), ('GPLv2', 67), ('Mailing-List-Servers', 67), ('Freeware', 67), ('Real-Time-Strategy', 67), ('Ham-Radio', 67)]
# Count of test label:
#  [('Software-Development', 1407), ('Internet', 1211), ('Web', 897), ('Libraries', 834), ('Communications', 679), ('Utilities', 510), ('Dynamic-Content', 470), ('Networking', 451), ('Games/Entertainment', 438), ('Scientific/Engineering', 336), ('Database', 334), ('Systems-Administration', 298), ('Security', 294), ('Desktop-Environment', 286), ('Monitoring', 285), ('GPL', 270), ('Office/Business', 230), ('Email', 224), ('Site-Management', 194), ('Information-Management', 165), ('Text-Processing', 164), ('Java-Libraries', 159), ('Chat', 148), ('education', 141), ('Archiving', 137), ('Front-Ends', 131), ('Application-Frameworks', 128), ('php-classes', 118), ('Testing', 112), ('CGI-Tools/Libraries', 101), ('Filters', 98), ('Cryptography', 97), ('Code-Generators', 92), ('Mathematics', 90), ('HTTP-Servers', 88), ('Text-Editors', 87), ('Build-Tools', 86), ('Interpreters', 81), ('GNOME', 77), ('IRC', 76), ('Firewalls', 76), ('Financial', 76), ('File-Sharing', 72), ('Arcade', 69), ('Filesystems', 68), ('Hardware', 67), ('Indexing/Search', 67), ('Python-Modules', 67), ('Compilers', 66), ('Puzzle-Games', 66), ('Logging', 62), ('Documentation', 59), ('Quality-Assurance', 59), ('backup', 59), ('News/Diary', 56), ('Database-Engines/Servers', 55), ('Log-Analysis', 55), ('Installation/Setup', 53), ('Role-Playing', 52), ('User-Interfaces', 52), ('Version-Control', 49), ('Turn-Based-Strategy', 49), ('tools', 49), ('Visualization', 48), ('KDE', 48), ('Scheduling', 48), ('Telephony', 46), ('Emulators', 44), ('Other/Nonlisted-Topic', 43), ('Debuggers', 41), ('Integrated-Development-Environments-(IDE)', 41), ('Widget-Sets', 41), ('Browsers', 41), ('FTP', 40), ('groupware', 40), ('DNS', 39), ('API', 39), ('Clustering/Distributed-Networks', 39), ('Perl-Modules', 39), ('Email-Clients-(MUA)', 39), ('Proxy-Servers', 39), ('Window-Manager', 37), ('Artificial-Intelligence', 37), ('LGPL', 36), ('Message-Boards', 34), ('Document-Repositories', 33), ('File-Managers', 33), ('Compression', 32), ('Simulation', 31), ('Shells', 30), ('Embedded-Systems', 29), ('Accounting', 28), ('Mail-Transport-Agents', 28), ('printing', 27), ('mud', 27), ('Usenet-News', 26), ('Linguistic', 26), ('Records-Management', 25), ('Freeware', 24), ('BBS', 23), ('Diagnostics', 23), ('Packaging', 22), ('Computer-Aided-Instruction-(CAI)', 21), ('First-Person-Shooters', 21), ('Bug-Tracking', 21), ('Astronomy', 21), ('Benchmark', 21), ('Bioinformatics', 21), ('CVS', 21), ('Recovery-Tools', 21), ('Software-Distribution-Tools', 20), ('General', 20), ('Medical-Science', 20), ('Electronic-Design-Automation-(EDA)', 20), ('php-class', 18), ('Object-Brokering', 18), ('Internet-Phone', 18), ('Real-Time-Strategy', 18), ('Indexing', 17), ('BSD-Original', 17), ('GPLv2', 17), ('Point-Of-Sale', 16), ('Boot', 16), ('Conferencing', 15), ('Metadata/Semantic-Models', 15), ('Ruby-Modules', 15), ('Link-Checking', 14), ('Home-Automation', 13), ('Wiki', 13), ('Chemistry', 12), ('Ham-Radio', 12), ('Mirroring', 11), ('Workflow-Frameworks', 11), ('Mailing-List-Servers', 11), ('Operating-System-Kernels', 11), ('Address-Book', 11), ('Geographical', 11), ('GPLv3', 10), ('Artistic-Software', 7), ('Video', 4), ('Window-Maker', 4), ('XML', 2), ('3D-Modeling', 1), ('Linux-Distributions', 1), ('IMAP', 1), ('POP3', 1), ('Graphics', 1)]
# Avg length of train text: 312.16399484061174
# Avg length of test text: 302.2172789366808

# %%
# add label description
with open('label-description.jsonl') as f:
    label_desc = f.readlines()
    label_desc = list(map(json.loads, label_desc))
    label_desc = {line['label']: line['description'] for line in label_desc}

for line in shuffle_train:
    label_text = line['labels'][0]
    for i, label in enumerate(line['labels']):
        line['labels'][i] = label2id[label]
    line['label_description'] = label_desc[label_text]

for line in test:
    label_text = line['labels'][0]
    for i, label in enumerate(line['labels']):
        line['labels'][i] = label2id[label]
    line['label_description'] = label_desc[label_text]

with open(f'{state}/train.json', 'w') as f:
    json.dump(shuffle_train, f, ensure_ascii=False, indent=2)

with open(f'{state}/test.json', 'w') as f:
    json.dump(test, f, ensure_ascii=False, indent=2)

# %%
# add label description
with open('label-description-with-example.jsonl') as f:
    label_desc = f.readlines()
    label_desc = list(map(json.loads, label_desc))
    label_desc = {line['label']: line['description'] for line in label_desc}

for line in shuffle_train:
    label_text = id2label[line['labels'][0]]
    line['label_description'] = label_desc[label_text]

for line in test:
    label_text = id2label[line['labels'][0]]
    line['label_description'] = label_desc[label_text]

with open(f'{state}/train-with-example.json', 'w') as f:
    json.dump(shuffle_train, f, ensure_ascii=False, indent=2)

with open(f'{state}/test-with-example.json', 'w') as f:
    json.dump(test, f, ensure_ascii=False, indent=2)
